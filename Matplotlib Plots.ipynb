# %% [markdown]
# Number Line

# %%
"""
Number Line

#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

-*- coding: utf-8 -*-
Created on Mon Nov 26 05:37:45 2018
@author: MrBrenzo
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as patches



# Setup a plot such that only the bottom spine is shown
def setup(ax):
    """creates number line .gif file for math homework"""
    ax.spines['right'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.yaxis.set_major_locator(ticker.NullLocator())
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.tick_params(which='major', width=1.0)
    ax.tick_params(which='major', length=8)
    ax.tick_params(which='minor', width=0.75)
    ax.tick_params(which='minor', length=2.5)
    # set range of number line here at set.xlim
    ax.set_xlim(-6, 7)
    ax.set_ylim(0, 1)
    ax.patch.set_alpha(0.0)
    
# adjust size of figure here
plt.figure(figsize=(16, 12))
n = 8
# set of sbuplot for ax
ax = plt.subplot(n, 1, 1)
setup(ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
#ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# identify zero cross here
#ax.axvline(8, ls='-', color='r')
#ax.axvline(-2, ls='-', color='r')
ax.axvline(-4, ls='-', color='b')
ax.axvline(5, ls='-', color='b')

ax.annotate('undefined point', xy=(-4, 0.1), xytext=(-3.2, .15), fontsize=18, color='blue', arrowprops=dict(facecolor='blue', shrink=0.05))
ax.annotate('undefined point', xy=(5, 0.1), xytext=(2.5, .15), fontsize=18, color='blue', arrowprops=dict(facecolor='blue', shrink=0.05))

# identify test cases here
ax.text(.075,0.829, 'x=-5\n=3.34', fontsize='15', horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)
#ax.text(.29,0.829, 'x=2\n=-3/8=-0.375', fontsize='15', horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)
ax.text(.50,0.829, 'x=-1\n=3*sqrt(2)(i)', fontsize='15', horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)
#ax.text(.80,0.829, 'x=2\n=-40', fontsize='15', horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)
ax.text(.930,0.829, 'x=6\n=3.34', fontsize='15', horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)

# Push the top of the top axes outside the figure because we only show the bottom spine.
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=1.05)
plt.show()

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *

x = np.linspace(-10, 10, 9999)
#x1 = x[x]
x1=x
fig, ax = plt.subplots()




def find_point(input_point, a, b, c, d, clr):
    try:
        x_point=float(input_point)
        y_point = 0
        y_point=(1/x_point)
        ax.plot(x_point, y_point, 'o')
        y_annotate = y_point * 1.2
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=10)
    except:
        ax.axvline(x=i, ls='--', color='r')
        
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)
    
    

a=1
b=1
c=1
d=1

find_point(.75, a, b, c, d, 'r')
find_point(-2, a, b, c, d, 'r')
find_point(-3, a, b, c, d, 'r')
find_point(.5, a, b, c, d, 'r')
find_point(-4, a, b, c, d, 'r')
find_point(-5, a, b, c, d, 'r')#'''

y=[(1/i) for i in x1]
    

ax.grid(True)
ax.set_ylim([-5, 5])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$f(x)=\frac{1}{x}$', fontsize=28)

try:
    ax.plot(x1, y, label=r'$f(x)=\frac{1}{x}$') #latex keyword label for legend
    plt.axvline(x=0, ls='--', color='b', label=r'$f(x)=\frac{1}{x}$ is' + '\nundefined') #latex keyword label for legend
    ax.legend()
except:
    ax.axvline(x1=i, ls='--', color='b') #why doesnt this work here?
# Out:
# C:\Users\MrBrenzo\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *

x = np.linspace(-6, 0, 9999)
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point=float(input_point)
        y_point = 0
        y_point=a*input_point**2 + b*input_point + c
        ax.plot(x_point, y_point, 'o')
        y_annotate = y_point + .2
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)
    except:
        ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?
        
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)

a=2
b=12
c=10
d=0

find_point(0, a, b, c, d, 'r')
find_point(-4, a, b, c, d, 'r')
find_point(-2, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(-5, a, b, c, d, 'r')#'''

y=[(a*i**2 + b*i + c) for i in x]

ax.grid(True)
ax.set_ylim([-12, 2])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$f(x)=x^2$', fontsize=28)
try:
    ax.plot(x, y, label=r'$f(x)=x^2$') #latex keyword label for legend
    ax.legend(loc='lower right')
except:
    ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(-4, 4, 9999)
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point=float(input_point)
        y_point = 0
        y_point=round(a*input_point**3 + b*input_point**2 + c*input_point + d)
        ax.plot(x_point, y_point,'o')
        y_annotate = y_point + .2
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)
    except:
        ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?
        
        
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)


a=1
b=0
c=0
d=0

find_point(1, a, b, c, d, 'r')
find_point(-2, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(2, a, b, c, d, 'r')#'''


y=[(a*i**3 + b*i**2 + c*i + d) for i in x]

ax.grid(True)
ax.set_ylim([-10, 10])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$f(x)=x^3$', fontsize=28)

try:
    ax.plot(x, y, label=r'$f(x)=x^3$') #latex keyword label for legend
    ax.legend(loc='upper left')
except:
    ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(-4, 4, 9999)
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        y_point=(a*input_point + b)
        ax.plot(x_point, y_point, 'o')
        y_annotate = y_point + .2
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)
    except:
        ax.axvline(x=i, ls='--', color='r')

        
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)


a=1
b=0
c=0
d=0

find_point(1, a, b, c, d, 'r')
find_point(-2, a, b, c, d, 'r')
find_point(-4, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(4, a, b, c, d, 'r')
find_point(2, a, b, c, d, 'r')#'''


y=[(a*i + b) for i in x]

ax.grid(True)
ax.set_ylim([-10, 10])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$f(x)=x$', fontsize=28)

try:
    ax.plot(x, y, label=r'$f(x)=x$') #latex keyword label for legend
    ax.legend(loc='upper left')
except:
    ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(-6, 6, 9999)
x1 = x[x<-2]
temp = x[x>=-2]
x2 = temp[temp<2]
x3 = x[x>=2]
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        if x_point<2:
            y_point=(a*input_point + b) 
        if -2<=x_point<2:
            y_point=(a*input_point**3 + b*input_point**2 + c*input_point + d)
        if x_point>=2:
            y_point=(a*input_point**2 + b*input_point + c)
        ax.plot(x_point, y_point, 'o', markersize=9)
        y_annotate = y_point + .4
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)#'''
    except:
        return(none)
     
def find_empty_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        if x_point<2:
            y_point=(a*input_point + b) 
        if -2<=x_point<2:
            y_point=(a*input_point**3 + b*input_point**2 + c*input_point + d)
        if x_point>=2:
            y_point=(a*input_point**2 + b*input_point + c)
        ax.plot(x_point, y_point, 'o', fillstyle='none', markersize=9)
        y_annotate = y_point + .4
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)#'''
    except:
        return(none)
    
    
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)



a=1
b=0
c=0
d=0

find_point(1, a, b, c, d, 'r')
#find_empty_point(1.99, a, b, c, d, 'r')
#find_empty_point(-2.01, a, b, c, d, 'r')
find_point(-2, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(3, a, b, c, d, 'r')
find_point(2, a, b, c, d, 'r')
find_point(-3, a, b, c, d, 'r')

y1=[(a*i + b) for i in x1]
y2=[(a*i**3 + b*i**2 + c*i + d) for i in x2]
y3=[(a*i**2 + b*i + c) for i in x3]

ax.grid(True)
ax.set_ylim([-10, 20])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Multi Plot', fontsize=28)

try:
    ax.plot(x1, y1, label=r'$f(x)=x$') #latex keyword label for legend
    ax.plot(x2, y2, label=r'$f(x)=x^3$') #latex keyword label for legend
    ax.plot(x3, y3, label=r'$f(x)=x^2$') #latex keyword label for legend
    ax.legend(loc='upper left')
except:
    ax.axvline(x=i, ls='--', color='r')

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(-4, 4, 9999)
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        y_point=np.sqrt(x_point+1)
        ax.plot(x_point, y_point, 'o')
        y_annotate = y_point**1.5
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)
    except:
        ax.axvline(x=i, ls='--', color='r')

        
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)


a=1
b=0
c=0
d=0

find_point(1, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(4, a, b, c, d, 'r')
find_point(2, a, b, c, d, 'r')


y=np.sqrt([(i+1) for i in x])

ax.grid(True)
ax.set_ylim([-4, 8])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$f(x)=\sqrt{x+1}$' + '\nOn the real plane only', fontsize=20)

try:
    ax.plot(x, y, label=r'$f(x)=\sqrt{x+1}$') #latex keyword label for legend
    ax.legend(loc='upper left')
    plt.axvspan(-5, -1, color='yellow', alpha=0.5, label=r'$i$')  #undefined ranges
except:
    ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?
# Out:
# C:\Users\MrBrenzo\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in sqrt

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(0, 6.3, 9999)
y1 = np.sin(x)
y2 = np.sin(x**2)
y3 = np.sin(x)**2

fig, ax = plt.subplots()

ax.grid(True)
ax.set_ylim([-1.5, 1.5])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$\sin(x)$', fontsize=28)

try:
    ax.plot(x, y1, label=r'$\sin(x)$') #latex keyword label for legend
    ax.plot(x, y2, label=r'$\sin(x^2)$') #latex keyword label for legend
    ax.plot(x, y3, label=r'$\sin^2(x)$') #latex keyword label for legend
    ax.legend(loc='upper left')
except:
    ax.axvline(x=i, ls='--', color='b') #why doesnt this work here?

# %%
#shift + enter: run cell
#control + enter: run cell in-place
#alt + enter: run cell, insert below

import matplotlib.pyplot as plt
import numpy as np
from decimal import *


x = np.linspace(-6, 6, 9999)
x1 = x[x>=1]
temp = x[x<1]
x2 = temp[temp>-1]
x3 = x[x<=-1]
fig, ax = plt.subplots()

def find_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        if x_point>=1:
            y_point=(1-input_point)
        if -1<x_point<1:
            y_point=(input_point**2-1)
        if x_point<=-1:
            y_point=(-1-input_point)
        ax.plot(x_point, y_point, 'o', markersize=9)
        y_annotate = y_point + .4
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)#'''
        print(point_str)
    except:
        return(none)
     
def find_empty_point(input_point, a, b, c, d, clr):
    try:
        x_point = float(input_point)
        y_point = 0
        if x_point<-2:
            y_point=(a*input_point + b) 
        if -2<=x_point<=3:
            y_point=(a*input_point**3 + b*input_point**2 + c*input_point + d)
        if x_point>3:
            y_point=(a*input_point**2 + b*input_point + c)
        ax.plot(x_point, y_point, 'o', fillstyle='none', markersize=9)
        y_annotate = y_point + .4
        point_str = '(' + str(rounding_funct(x_point)) + ', ' + str(rounding_funct(y_point)) + ')'
        ax.annotate(point_str, xy=(x_point, y_annotate), fontsize=17)#'''
    except:
        return(none)
    
    
def rounding_funct(input_num):
    try:
        return(Decimal(float(input_num)).quantize(Decimal('.01'), rounding=ROUND_HALF_UP))
    except:
        return(none)



a=1
b=0
c=0
d=0

find_point(-3, a, b, c, d, 'r')
#find_point(-2, a, b, c, d, 'r')
find_point(-1, a, b, c, d, 'r')
find_point(0, a, b, c, d, 'r')
find_point(1, a, b, c, d, 'r')
find_point(2, a, b, c, d, 'r')
#find_point(3, a, b, c, d, 'r')
#find_point(4, a, b, c, d, 'r')
#find_empty_point(1.99, a, b, c, d, 'r')
#find_empty_point(-2.01, a, b, c, d, 'r')


y1=[(1-i) for i in x1]
y2=[(i**2-1) for i in x2]
y3=[(-1-i) for i in x3]

ax.grid(True)
ax.set_ylim([-2, 3])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Problem 13')

try:
    ax.plot(x1, y1, label=r'$f(x)=1-x$') #latex keyword label for legend
    ax.plot(x2, y2, label=r'$f(x)=x^2-1$') #latex keyword label for legend
    ax.plot(x3, y3, label=r'$f(x)=-1-x$') #latex keyword label for legend
    ax.legend(loc='lower left')
except:
    ax.axvline(x=i, ls='--', color='r')
# Out:
# (-3.00, 2.00)
# (-1.00, 0.00)
# (0.00, -1.00)
# (1.00, 0.00)
# (2.00, -1.00)
